# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Plotting
interval = 1000

reward_hist_no_exp = pickle.load(open('all_reward_no_exp.p','rb'))
reward_hist_dropout = pickle.load(open('all_reward_dropout.p','rb'))
reward_hist_narrow = pickle.load(open('all_reward_narrow.p','rb'))

def get_mean_var(reward_hist):
    ts = pd.Series(reward_hist[:20000])
    return pd.rolling_mean(ts, interval), pd.rolling_var(ts, interval)

reward_hist_no_exp_mean, reward_hist_no_exp_var = get_mean_var(reward_hist_no_exp)
reward_hist_dropout_mean, reward_hist_dropout_var = get_mean_var(reward_hist_dropout)
reward_hist_narrow_mean, reward_hist_narrow_var = get_mean_var(reward_hist_narrow)

fig,axe = plt.subplots(2,1,figsize=(6,6))
plt.suptitle('Policy Gradient Breakout', fontsize=18)
axe[0].set_ylim(1,8)
axe[0].plot([7]*20000,'b--')
axe[0].plot(reward_hist_no_exp_mean,label='ANN')
axe[0].plot(reward_hist_dropout_mean,label='Dropout')
axe[0].plot(reward_hist_narrow_mean,label='Narrow ANN')
axe[0].set_xlabel('Episode')
axe[0].set_ylabel('Rewards')
axe[0].legend(loc=4,fontsize=10) 
axe[0].set_title('Mean',fontsize=15)
axe[1].set_ylim(0,16)
axe[1].plot(reward_hist_no_exp_var,label='ANN')
axe[1].plot(reward_hist_dropout_var,label='Drop out')
axe[1].plot(reward_hist_narrow_var,label='Narrow ANN')
axe[1].set_xlabel('Episode')
axe[1].set_title('Variance',fontsize=15)
plt.subplots_adjust(hspace=0.5)
plt.show()
fig.savefig('Breakout_comp.jpg')
# Out:
# G:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=1000,center=False).mean()
# G:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: pd.rolling_var is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=1000,center=False).var()
